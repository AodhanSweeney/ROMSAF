# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import xarray as xr
from scipy.interpolate import interp1d
from netCDF4 import Dataset

# %%
dr_versions = ['cdr', 'icdr']
cdr_satellites = ['cosmic', 'metop']
icdr_satellites = ['metop']
ROM_SAF_path_generic = '/home/bdc2/aodhan/ROM_SAF/www.romsaf.org/pub/{cdr_version}/profs/{satellite}/atm/'
heights = np.linspace(5,35,301)*1000
month_strings = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

ROM_SAF_temp_profiles = []
for dr in dr_versions:
    if dr == 'cdr':
        dr_string = 'cdr/v1.0'
        satellites = cdr_satellites
    elif dr == 'icdr':
        dr_string = 'icdr/v1-series'
        satellites = icdr_satellites
    for sat in satellites:
        print('Satellite: ', sat)
        ROM_SAF_path_satellite = ROM_SAF_path_generic.format(cdr_version=dr_string, satellite=sat)
        for year in range(2006, 2021):
            print('Year: ', str(year))
            for month in month_strings:
                RO_daily_data_paths = glob.glob(ROM_SAF_path_satellite + str(year) 
                                                + '/' + str(year) + '-' + month + '*')
                if len(RO_daily_data_paths) == 0:
                    continue
                month_of_RO_data = []
                for day in RO_daily_data_paths:
                    datafiles_of_day = glob.glob(day + '/*')
                    
                    for datafile in datafiles_of_day:
                        if datafile[-11:] == 'non-nominal':
                            continue
                        else:
                            # extract temp and alt info from RO
                            RO = Dataset(datafile)
                            
                            dry_temp = RO.variables['dry_temp'][0]
                            alt = RO.variables['alt_refrac'][0]
                            # above is the height according to page 51/51 at url below
                            # https://www.romsaf.org/product_documents/romsaf_pum.pdf 
                            
                            # find RO location and time
                            lat = np.array(RO.variables['lat_tp'])
                            lon = np.array(RO.variables['lon_tp'])
                            day = RO.variables['day'][0]
                            hour = RO.variables['hour'][0]
    
                            # get lat and lon of RO based on 17 km tangent point
                            altm17 = np.abs(alt-17000)
                            idx_17km = np.nanargmin(altm17) 
                            lat_17km = lat[0][idx_17km]
                            lon_17km = lon[0][idx_17km]
                            
                            # interpolate temperature profile
                            temp_interp = interp1d(alt, dry_temp, kind='cubic', bounds_error=False)
                            temp_100m_spacing = temp_interp(heights)

                            # append data
                            month_of_RO_data.append([day, hour, lat_17km, lon_17km, temp_100m_spacing])

                # save month of data
                file_name = 'DryTempProf_{satellite}_{month}_{year}_5_35km'.format(satellite=sat, month=month, year=str(year))
                file_path = ROM_SAF_path_satellite + str(year) + '/' + file_name
                np.save(file_path, month_of_RO_data)
# Out:
# Satellite:  cosmic
# Year:  2006
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Year:  2007
# Year:  2008

# %%
import time 
start = time.time()
dr_versions = ['icdr']
cdr_satellites = ['champ', 'cosmic', 'grace', 'metop']
icdr_satellites = ['metop']
ROM_SAF_path_generic = '/home/bdc2/aodhan/ROM_SAF/www.romsaf.org/pub/{cdr_version}/profs/{satellite}/atm/'
heights = np.linspace(5,35,301)*1000
month_strings = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

ROM_SAF_temp_profiles = []
for dr in dr_versions:
    if dr == 'cdr':
        dr_string = 'cdr/v1.0'
        satellites = cdr_satellites
    elif dr == 'icdr':
        dr_string = 'icdr/v1-series'
        satellites = icdr_satellites
    for sat in satellites:
        print(sat)
        ROM_SAF_path_satellite = ROM_SAF_path_generic.format(cdr_version=dr_string, satellite=sat)
        for year in range(2001, 2023):
            print('Year: ', str(year))
            for month in month_strings:
                RO_daily_data_paths = glob.glob(ROM_SAF_path_satellite + str(year) 
                                                + '/' + str(year) + '-' + month + '*')
                if len(RO_daily_data_paths) == 0:
                    print('No data for {month} of {year}'.format(month=month, year=str(year)))
                    continue
                month_of_RO_data = []
                for day in RO_daily_data_paths:
                    datafiles_of_day = glob.glob(day + '/*')
                    
                    for datafile in datafiles_of_day:
                        if datafile[-11:] == 'non-nominal':
                            continue
                        else:
                            # extract temp and alt info from RO
                            RO = Dataset(datafile)
                            dry_temp = RO.variables['dry_temp'][0]
                            alt = RO.variables['alt_refrac'][0]
                            # above is the height according to page 51/51 at url below
                            # https://www.romsaf.org/product_documents/romsaf_pum.pdf 
                            
                            # find RO location
                            lat = np.array(RO.variables['lat_tp'])
                            lon = np.array(RO.variables['lon_tp'])
                            altm17 = np.abs(alt-17000)
                            idx_17km = np.nanargmin(altm17) # 17 Km tangent point
                            lat_17km = lat[0][idx_17km]
                            lon_17km = lon[0][idx_17km]
                            
                            # interpolate temperature profile
                            temp_interp = interp1d(alt, dry_temp, kind='cubic', bounds_error=False)
                            temp_100m_spacing = temp_interp(heights)

                            # append data
                            month_of_RO_data.append([lat_17km, lon_17km, temp_100m_spacing])
                
                # save month of data
                file_name = 'DryTempProf_{satellite}_{month}_{year}_5_35km'.format(satellite=sat, month=month, year=str(year))
                file_path = ROM_SAF_path_satellite + str(year) + '/' + file_name
                np.save(file_path, month_of_RO_data)
# Out:
# metop
# Year:  2001
# No data for 01 of 2001
# No data for 02 of 2001
# No data for 03 of 2001
# No data for 04 of 2001
# No data for 05 of 2001
# No data for 06 of 2001
# No data for 07 of 2001
# No data for 08 of 2001
# No data for 09 of 2001
# No data for 10 of 2001
# No data for 11 of 2001
# No data for 12 of 2001
# Year:  2002
# No data for 01 of 2002
# No data for 02 of 2002
# No data for 03 of 2002
# No data for 04 of 2002
# No data for 05 of 2002
# No data for 06 of 2002
# No data for 07 of 2002
# No data for 08 of 2002
# No data for 09 of 2002
# No data for 10 of 2002
# No data for 11 of 2002
# No data for 12 of 2002
# Year:  2003
# No data for 01 of 2003
# No data for 02 of 2003
# No data for 03 of 2003
# No data for 04 of 2003
# No data for 05 of 2003
# No data for 06 of 2003
# No data for 07 of 2003
# No data for 08 of 2003
# No data for 09 of 2003
# No data for 10 of 2003
# No data for 11 of 2003
# No data for 12 of 2003
# Year:  2004
# No data for 01 of 2004
# No data for 02 of 2004
# No data for 03 of 2004
# No data for 04 of 2004
# No data for 05 of 2004
# No data for 06 of 2004
# No data for 07 of 2004
# No data for 08 of 2004
# No data for 09 of 2004
# No data for 10 of 2004
# No data for 11 of 2004
# No data for 12 of 2004
# Year:  2005
# No data for 01 of 2005
# No data for 02 of 2005
# No data for 03 of 2005
# No data for 04 of 2005
# No data for 05 of 2005
# No data for 06 of 2005
# No data for 07 of 2005
# No data for 08 of 2005
# No data for 09 of 2005
# No data for 10 of 2005
# No data for 11 of 2005
# No data for 12 of 2005
# Year:  2006
# No data for 01 of 2006
# No data for 02 of 2006
# No data for 03 of 2006
# No data for 04 of 2006
# No data for 05 of 2006
# No data for 06 of 2006
# No data for 07 of 2006
# No data for 08 of 2006
# No data for 09 of 2006
# No data for 10 of 2006
# No data for 11 of 2006
# No data for 12 of 2006
# Year:  2007
# No data for 01 of 2007
# No data for 02 of 2007
# No data for 03 of 2007
# No data for 04 of 2007
# No data for 05 of 2007
# No data for 06 of 2007
# No data for 07 of 2007
# No data for 08 of 2007
# No data for 09 of 2007
# No data for 10 of 2007
# No data for 11 of 2007
# No data for 12 of 2007
# Year:  2008
# No data for 01 of 2008
# No data for 02 of 2008
# No data for 03 of 2008
# No data for 04 of 2008
# No data for 05 of 2008
# No data for 06 of 2008
# No data for 07 of 2008
# No data for 08 of 2008
# No data for 09 of 2008
# No data for 10 of 2008
# No data for 11 of 2008
# No data for 12 of 2008
# Year:  2009
# No data for 01 of 2009
# No data for 02 of 2009
# No data for 03 of 2009
# No data for 04 of 2009
# No data for 05 of 2009
# No data for 06 of 2009
# No data for 07 of 2009
# No data for 08 of 2009
# No data for 09 of 2009
# No data for 10 of 2009
# No data for 11 of 2009
# No data for 12 of 2009
# Year:  2010
# No data for 01 of 2010
# No data for 02 of 2010
# No data for 03 of 2010
# No data for 04 of 2010
# No data for 05 of 2010
# No data for 06 of 2010
# No data for 07 of 2010
# No data for 08 of 2010
# No data for 09 of 2010
# No data for 10 of 2010
# No data for 11 of 2010
# No data for 12 of 2010
# Year:  2011
# No data for 01 of 2011
# No data for 02 of 2011
# No data for 03 of 2011
# No data for 04 of 2011
# No data for 05 of 2011
# No data for 06 of 2011
# No data for 07 of 2011
# No data for 08 of 2011
# No data for 09 of 2011
# No data for 10 of 2011
# No data for 11 of 2011
# No data for 12 of 2011
# Year:  2012
# No data for 01 of 2012
# No data for 02 of 2012
# No data for 03 of 2012
# No data for 04 of 2012
# No data for 05 of 2012
# No data for 06 of 2012
# No data for 07 of 2012
# No data for 08 of 2012
# No data for 09 of 2012
# No data for 10 of 2012
# No data for 11 of 2012
# No data for 12 of 2012
# Year:  2013
# No data for 01 of 2013
# No data for 02 of 2013
# No data for 03 of 2013
# No data for 04 of 2013
# No data for 05 of 2013
# No data for 06 of 2013
# No data for 07 of 2013
# No data for 08 of 2013
# No data for 09 of 2013
# No data for 10 of 2013
# No data for 11 of 2013
# No data for 12 of 2013
# Year:  2014
# No data for 01 of 2014
# No data for 02 of 2014
# No data for 03 of 2014
# No data for 04 of 2014
# No data for 05 of 2014
# No data for 06 of 2014
# No data for 07 of 2014
# No data for 08 of 2014
# No data for 09 of 2014
# No data for 10 of 2014
# No data for 11 of 2014
# No data for 12 of 2014
# Year:  2015
# No data for 01 of 2015
# No data for 02 of 2015
# No data for 03 of 2015
# No data for 04 of 2015
# No data for 05 of 2015
# No data for 06 of 2015
# No data for 07 of 2015
# No data for 08 of 2015
# No data for 09 of 2015
# No data for 10 of 2015
# No data for 11 of 2015
# No data for 12 of 2015
# Year:  2016
# No data for 01 of 2016
# No data for 02 of 2016
# No data for 03 of 2016
# No data for 04 of 2016
# No data for 05 of 2016
# No data for 06 of 2016
# No data for 07 of 2016
# No data for 08 of 2016
# No data for 09 of 2016
# No data for 10 of 2016
# No data for 11 of 2016
# No data for 12 of 2016
# Year:  2017
# Year:  2018
# Year:  2019
# Year:  2020
# Year:  2021
# Year:  2022
# No data for 06 of 2022
# No data for 07 of 2022
# No data for 08 of 2022
# No data for 09 of 2022
# No data for 10 of 2022
# No data for 11 of 2022
# No data for 12 of 2022
